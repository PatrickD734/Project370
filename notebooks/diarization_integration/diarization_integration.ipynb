# %% [markdown]
# # Speaker Diarization Pipeline Integration
#
# **Assignment:** Wire pyannote speaker diarization into the Foreign Whispers pipeline so multi-speaker videos produce per-speaker labeled segments.
#
# ## Pipeline Flow
#
# ```
# CURRENT:  Download → Transcribe → Translate → TTS → Stitch
# TARGET:   Download → Transcribe → Diarize → Translate → TTS (per-speaker) → Stitch
#                                     ↑
#                               YOUR WORK HERE
# ```
#
# ## Prerequisites
#
# - Docker Compose stack is running: `docker compose --profile nvidia up -d`
# - `FW_HF_TOKEN` is set in your `.env` or environment
# - You have accepted the [pyannote/speaker-diarization-3.1](https://huggingface.co/pyannote/speaker-diarization-3.1) model license on HuggingFace
# - A multi-speaker test video is in `video_registry.yml` and downloaded

# %% [markdown]
# ## Provided Code (Read First)
#
# | File | What it does |
# | ---- | ------------ |
# | `foreign_whispers/diarization.py` | `diarize_audio(audio_path, hf_token)` — calls pyannote, returns `[{start_s, end_s, speaker}]` |
# | `api/src/services/alignment_service.py` | `AlignmentService.diarize()` — service wrapper |
# | `api/src/core/config.py` | `Settings.hf_token` — reads `FW_HF_TOKEN` env var |
# | `pipeline_data/speakers/` | Per-language directories with reference WAV files for TTS voice cloning |

# %%
# Setup: add project root to path
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: /home/zuhair/Desktop/foreign-whispers

# %% [markdown]
# ---
#
# ## Task 1: Segment-Speaker Merge Function
#
# **Goal:** Write a pure function that assigns a speaker label to each transcription segment based on diarization output.
#
# **Algorithm:** For each transcription segment, find which diarization speaker has the most temporal overlap with that segment's `[start, end]` range.
#
# **File to modify:** `foreign_whispers/diarization.py` (add function to existing file)

# %% [markdown]
# ### 1.1 — Read the existing diarization code

# %%
# Read the existing diarization module
diar_path = PROJECT_ROOT / "foreign_whispers" / "diarization.py"
print(diar_path.read_text())
# Out:
# """Speaker diarization using pyannote.audio.
#
# Extracted from notebooks/foreign_whispers_pipeline.ipynb (M2-align).
#
# Optional dependency: pyannote.audio
#     pip install pyannote.audio
# Requires accepting the pyannote/speaker-diarization-3.1 licence on HuggingFace
# and providing an HF token.  Returns empty list with a warning if the dep is
# absent or the token is missing.
# """
# import logging
#
# logger = logging.getLogger(__name__)
#
#
# def diarize_audio(audio_path: str, hf_token: str | None = None) -> list[dict]:
#     """Return speaker-labeled intervals for *audio_path*.
#
#     Returns:
#         List of ``{start_s: float, end_s: float, speaker: str}``.
#         Empty list when pyannote.audio is absent, token is missing, or diarization fails.
#     """
#     if not hf_token:
#         logger.warning("No HF token provided — diarization skipped.")
#         return []
#
#     try:
#         from pyannote.audio import Pipeline
#     except (ImportError, TypeError):
#         logger.warning("pyannote.audio not installed — returning empty diarization.")
#         return []
#
#     try:
#         pipeline    = Pipeline.from_pretrained(
#             "pyannote/speaker-diarization-3.1",
#             use_auth_token=hf_token,
#         )
#         diarization = pipeline(audio_path)
#         return [
#             {"start_s": turn.start, "end_s": turn.end, "speaker": speaker}
#             for turn, _, speaker in diarization.itertracks(yield_label=True)
#         ]
#     except Exception as exc:
#         logger.warning("Diarization failed for %s: %s", audio_path, exc)
#         return []

# %% [markdown]
# ### 1.2 — Write the tests first (TDD)
#
# Run the tests below. They will **fail** because `assign_speakers` doesn't exist yet. That's expected.

# %%
# These tests define the contract for assign_speakers.
# DO NOT modify the tests — make your implementation pass them.

def run_tests():
    from foreign_whispers.diarization import assign_speakers
    
    passed, failed = 0, 0
    
    # Test 1: Single speaker
    try:
        segments = [
            {"id": 0, "start": 0.0, "end": 3.0, "text": "Hello world"},
            {"id": 1, "start": 3.5, "end": 6.0, "text": "How are you"},
        ]
        diarization = [
            {"start_s": 0.0, "end_s": 7.0, "speaker": "SPEAKER_00"},
        ]
        result = assign_speakers(segments, diarization)
        assert len(result) == 2
        assert result[0]["speaker"] == "SPEAKER_00"
        assert result[1]["speaker"] == "SPEAKER_00"
        assert result[0]["text"] == "Hello world"
        print("✓ Test 1 passed: single speaker")
        passed += 1
    except Exception as e:
        print(f"✗ Test 1 FAILED: {e}")
        failed += 1
    
    # Test 2: Two speakers
    try:
        segments = [
            {"id": 0, "start": 0.0, "end": 4.0, "text": "Speaker A talking"},
            {"id": 1, "start": 5.0, "end": 9.0, "text": "Speaker B talking"},
            {"id": 2, "start": 10.0, "end": 14.0, "text": "Speaker A again"},
        ]
        diarization = [
            {"start_s": 0.0, "end_s": 4.5, "speaker": "SPEAKER_00"},
            {"start_s": 4.5, "end_s": 9.5, "speaker": "SPEAKER_01"},
            {"start_s": 9.5, "end_s": 15.0, "speaker": "SPEAKER_00"},
        ]
        result = assign_speakers(segments, diarization)
        assert result[0]["speaker"] == "SPEAKER_00"
        assert result[1]["speaker"] == "SPEAKER_01"
        assert result[2]["speaker"] == "SPEAKER_00"
        print("✓ Test 2 passed: two speakers")
        passed += 1
    except Exception as e:
        print(f"✗ Test 2 FAILED: {e}")
        failed += 1
    
    # Test 3: Empty diarization defaults to SPEAKER_00
    try:
        segments = [{"id": 0, "start": 0.0, "end": 3.0, "text": "Hello"}]
        result = assign_speakers(segments, [])
        assert result[0]["speaker"] == "SPEAKER_00"
        print("✓ Test 3 passed: empty diarization")
        passed += 1
    except Exception as e:
        print(f"✗ Test 3 FAILED: {e}")
        failed += 1
    
    # Test 4: Does not mutate input
    try:
        segments = [{"id": 0, "start": 0.0, "end": 3.0, "text": "Hello"}]
        original = segments[0].copy()
        assign_speakers(segments, [])
        assert segments[0] == original
        assert "speaker" not in segments[0]
        print("✓ Test 4 passed: no mutation")
        passed += 1
    except Exception as e:
        print(f"✗ Test 4 FAILED: {e}")
        failed += 1
    
    print(f"\n{'='*40}")
    print(f"Results: {passed} passed, {failed} failed")
    return failed == 0

# Run — expected to FAIL at this point
run_tests()
# Out:
# ✓ Test 1 passed: single speaker
# ✓ Test 2 passed: two speakers
# ✓ Test 3 passed: empty diarization
# ✓ Test 4 passed: no mutation
#
# ========================================
# Results: 4 passed, 0 failed
# True

# %% [markdown]
# ### 1.3 — Implement `assign_speakers`
#
# Open `foreign_whispers/diarization.py` and add the function below at the bottom of the file. Replace the `raise NotImplementedError` with your implementation.
#
# **Hints:**
# 1. Create a **copy** of each segment dict (don't mutate the input)
# 2. For each segment, compute overlap with every diarization interval:
#    ```python
#    overlap = max(0, min(seg_end, diar_end) - max(seg_start, diar_start))
#    ```
# 3. Pick the diarization interval with the **largest overlap**
# 4. If no overlap or diarization is empty, default to `"SPEAKER_00"`

# %%
# Stub — copy this into foreign_whispers/diarization.py (at the bottom)

def assign_speakers(
    segments: list[dict],
    diarization: list[dict],
) -> list[dict]:
    """Assign a speaker label to each transcription segment.

    For each segment, finds the diarization interval with the greatest
    temporal overlap and copies its speaker label. If diarization is
    empty, all segments default to ``SPEAKER_00``.

    Args:
        segments: Whisper-style ``[{id, start, end, text, ...}]``.
        diarization: pyannote-style ``[{start_s, end_s, speaker}]``.

    Returns:
        New list of segment dicts, each with an added ``speaker`` key.
        Original list is not mutated.
    """
    # ---- YOUR CODE HERE ----
    def assign_speakers(
    segments: list[dict],
    diarization: list[dict],
) -> list[dict]:
    result = []
    for seg in segments:
        seg_copy = seg.copy()
        seg_start = seg["start"]
        seg_end = seg["end"]
        best_speaker = "SPEAKER_00"
        best_overlap = 0.0
        for diar in diarization:
            overlap = max(0, min(seg_end, diar["end_s"]) - max(seg_start, diar["start_s"]))
            if overlap > best_overlap:
                best_overlap = overlap
                best_speaker = diar["speaker"]
        seg_copy["speaker"] = best_speaker
        result.append(seg_copy)
    return result
    raise NotImplementedError("Implement this function")
    # ---- END YOUR CODE ----

# %% [markdown]
# ### 1.4 — Re-run the tests
#
# After implementing, re-run the tests. All 4 should pass.

# %%
# Reload the module and re-run
import importlib
import foreign_whispers.diarization
importlib.reload(foreign_whispers.diarization)

assert run_tests(), "Some tests failed — fix your implementation before continuing."
# Out:
# ✓ Test 1 passed: single speaker
# ✓ Test 2 passed: two speakers
# ✓ Test 3 passed: empty diarization
# ✓ Test 4 passed: no mutation
#
# ========================================
# Results: 4 passed, 0 failed

# %% [markdown]
# ### 1.5 — Commit your work
#
# ```bash
# git add foreign_whispers/diarization.py
# git commit -m "feat: add assign_speakers merge function"
# ```

# %% [markdown]
# ---
#
# ## Task 2: Diarize API Endpoint
#
# **Goal:** Create `POST /api/diarize/{video_id}` that extracts audio, runs diarization, and returns speaker segments.
#
# **Files to create:**
# - `api/src/schemas/diarize.py`
# - `api/src/routers/diarize.py`
#
# **Files to modify:**
# - `api/src/main.py` (register the router)
# - `api/src/core/config.py` (add `diarizations_dir` property)

# %% [markdown]
# ### 2.1 — Add `diarizations_dir` to Settings
#
# Open `api/src/core/config.py` and add this property after `transcriptions_dir`:
#
# ```python
# @property
# def diarizations_dir(self) -> Path:
#     return self.data_dir / "diarizations"
# ```

# %% [markdown]
# ### 2.2 — Create the response schema
#
# Create `api/src/schemas/diarize.py`:

# %%
# Preview of the schema — create this file at api/src/schemas/diarize.py

schema_code = '''
"""Pydantic schemas for the diarize API contract."""

from pydantic import BaseModel


class DiarizeSpeakerSegment(BaseModel):
    start_s: float
    end_s: float
    speaker: str


class DiarizeResponse(BaseModel):
    video_id: str
    speakers: list[str]
    segments: list[DiarizeSpeakerSegment]
    skipped: bool = False
'''

schema_path = PROJECT_ROOT / "api" / "src" / "schemas" / "diarize.py"
schema_path.write_text(schema_code.strip() + "\n")
print(f"Created {schema_path}")
# Out:
# Created /home/zuhair/Desktop/foreign-whispers/api/src/schemas/diarize.py

# %% [markdown]
# ### 2.3 — Create the router (with stub)
#
# Create `api/src/routers/diarize.py`. The endpoint has a stub that returns `501 Not Implemented` — you will fill it in.

# %%
router_code = '''
"""POST /api/diarize/{video_id} — speaker diarization (issue fw-lua)."""

import asyncio
import json
import subprocess

from fastapi import APIRouter, HTTPException

from api.src.core.config import settings
from api.src.core.dependencies import resolve_title
from api.src.schemas.diarize import DiarizeResponse
from api.src.services.alignment_service import AlignmentService

router = APIRouter(prefix="/api")

_alignment_service = AlignmentService(settings=settings)


@router.post("/diarize/{video_id}", response_model=DiarizeResponse)
async def diarize_endpoint(video_id: str):
    """Run speaker diarization on a video's audio track.

    Steps:
    1. Extract audio from video via ffmpeg
    2. Run pyannote diarization
    3. Cache and return speaker segments
    """
    title = resolve_title(video_id)
    if title is None:
        raise HTTPException(status_code=404, detail=f"Video {video_id} not found")

    diar_dir = settings.diarizations_dir
    diar_dir.mkdir(parents=True, exist_ok=True)
    diar_path = diar_dir / f"{title}.json"

    # Return cached result
    if diar_path.exists():
        data = json.loads(diar_path.read_text())
        return DiarizeResponse(
            video_id=video_id,
            speakers=data.get("speakers", []),
            segments=data.get("segments", []),
            skipped=True,
        )

    # ---- YOUR CODE HERE ----
    # Step 1: Extract audio from video
    #   video_path = settings.videos_dir / f"{title}.mp4"
    #   audio_path = diar_dir / f"{title}.wav"
    #   Use subprocess.run to call:
    #     ffmpeg -i <video_path> -vn -acodec pcm_s16le -ar 16000 -y <audio_path>
    #
    # Step 2: Run diarization
    #   diar_segments = _alignment_service.diarize(str(audio_path))
    #
    # Step 3: Extract unique speakers
    #   speakers = sorted(set(s["speaker"] for s in diar_segments))
    #
    # Step 4: Cache result
    #   result = {"speakers": speakers, "segments": diar_segments}
    #   diar_path.write_text(json.dumps(result))
    #
    # Step 5: Return DiarizeResponse
    #   return DiarizeResponse(video_id=video_id, speakers=speakers, segments=diar_segments)
    #
    raise HTTPException(status_code=501, detail="Diarization not yet implemented")
    # ---- END YOUR CODE ----
'''

router_path = PROJECT_ROOT / "api" / "src" / "routers" / "diarize.py"
router_path.write_text(router_code.strip() + "\n")
print(f"Created {router_path}")
# Out:
# Created /home/zuhair/Desktop/foreign-whispers/api/src/routers/diarize.py

# %% [markdown]
# ### 2.4 — Register the router
#
# Open `api/src/main.py` and add these lines alongside the existing router registrations (around line 94):
#
# ```python
# from api.src.routers.diarize import router as diarize_router
# app.include_router(diarize_router)
# ```

# %% [markdown]
# ### 2.5 — Implement the endpoint
#
# Replace the `YOUR CODE HERE` block in `api/src/routers/diarize.py` with your implementation. Follow the numbered steps in the comments.

# %% [markdown]
# ### 2.6 — Rebuild and test

# %%
# Rebuild the API container
# !cd {PROJECT_ROOT} && docker compose --profile nvidia build api
# !cd {PROJECT_ROOT} && docker compose --profile nvidia up -d api
# Out:
# [+] Building 0.0s (0/1)
#  => [internal] load local bake definitions                                 0.0s
# [+] Building 0.2s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
# [+] Building 0.3s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
# [+] Building 0.4s (1/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
# [+] Building 0.5s (1/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.1s
#  => => transferring dockerfile: 1.18kB                                     0.0s
# [+] Building 0.7s (2/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
# [+] Building 0.9s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.2s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.2s
# [+] Building 1.0s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.3s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.3s
# [+] Building 1.2s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.5s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.5s
# [+] Building 1.3s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.6s
# [+] Building 1.5s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.8s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.8s
# [+] Building 1.6s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               0.9s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.9s
# [+] Building 1.8s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.1s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.1s
# [+] Building 1.9s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.2s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.2s
# [+] Building 2.1s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.4s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.4s
# [+] Building 2.2s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.5s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
# [+] Building 2.3s (3/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.5s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
# [+] Building 2.4s (4/5)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context:                                               0.0s
# [+] Building 2.5s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
# [+] Building 2.7s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          0.2s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  0.2s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  0.2s
# [+] Building 2.7s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          0.2s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  0.2s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  0.2s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  0.0s
# [+] Building 2.8s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          0.3s
#  => => transferring context: 21.50kB                                       0.1s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  0.3s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  0.0s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  0.3s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  0.1s
# [+] Building 3.0s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          0.4s
#  => => transferring context: 21.50kB                                       0.3s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  0.4s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  0.2s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  0.4s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  0.3s
# [+] Building 3.0s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 70.82kB                                       0.3s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  0.5s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  0.2s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  0.5s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  0.3s
# [+] Building 3.1s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          0.6s
#  => => transferring context: 170.70kB                                      0.5s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  0.6s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  0.4s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  0.6s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  0.5s
# [+] Building 3.3s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          0.8s
#  => => transferring context: 589.30kB                                      0.6s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  0.8s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  0.5s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  0.8s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  0.6s
# [+] Building 3.4s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 1.11MB                                        0.7s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  0.9s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  0.6s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  0.9s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  0.7s
# [+] Building 3.5s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.0s
#  => => transferring context: 2.00MB                                        0.8s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.0s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  0.7s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  0.8s
# [+] Building 3.6s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.1s
#  => => transferring context: 2.32MB                                        0.9s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  0.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.1s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  0.9s
# [+] Building 3.7s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.2s
#  => => transferring context: 3.10MB                                        1.1s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.2s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.0s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.2s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.1s
# [+] Building 3.9s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.4s
#  => => transferring context: 3.10MB                                        1.2s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.4s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.1s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.4s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.2s
# [+] Building 3.9s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.4s
#  => => transferring context: 3.44MB                                        1.2s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.4s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.2s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.4s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.2s
# [+] Building 4.0s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.5s
#  => => transferring context: 4.58MB                                        1.3s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.5s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.3s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.5s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.3s
# [+] Building 4.1s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.6s
#  => => transferring context: 5.13MB                                        1.4s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.6s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.4s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.6s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.5s
# [+] Building 4.2s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.7s
#  => => transferring context: 6.75MB                                        1.5s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.7s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.5s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.7s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.6s
# [+] Building 4.3s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.8s
#  => => transferring context: 9.11MB                                        1.6s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.8s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.6s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.8s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.7s
# [+] Building 4.4s (5/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 11.50MB                                       1.7s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  1.9s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.7s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  1.9s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 4.6s (6/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          2.1s
#  => => transferring context: 13.89MB                                       1.9s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.8s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 4.7s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          2.2s
#  => => transferring context: 19.04MB                                       2.0s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 4.9s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          2.4s
#  => => transferring context: 26.48MB                                       2.2s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.0s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          2.5s
#  => => transferring context: 29.75MB                                       2.3s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.2s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          2.7s
#  => => transferring context: 33.95MB                                       2.5s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.3s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          2.8s
#  => => transferring context: 37.49MB                                       2.6s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.4s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          2.9s
#  => => transferring context: 40.37MB                                       2.7s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.5s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          3.0s
#  => => transferring context: 44.18MB                                       2.8s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.7s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          3.1s
#  => => transferring context: 44.18MB                                       3.0s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.7s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          3.2s
#  => => transferring context: 46.14MB                                       3.0s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.8s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          3.3s
#  => => transferring context: 47.19MB                                       3.1s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.9s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          3.4s
#  => => transferring context: 47.19MB                                       3.2s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 5.9s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          3.4s
#  => => transferring context: 50.73MB                                       3.2s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 6.1s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          3.5s
#  => => transferring context: 54.01MB                                       3.4s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
# [+] Building 6.2s (7/15)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
# ...
#  => CACHED [stage-0 6/8] COPY --chown=appuser:appuser pyproject.toml uv.l  0.0s
#  => CACHED [stage-0 7/8] RUN --mount=type=cache,target=/root/.cache/uv     0.0s
#  => [stage-0 8/8] COPY --chown=appuser:appuser . .                         7.2s
#  => exporting to image                                                    17.2s
#  => => exporting layers                                                   13.6s
#  => => exporting manifest sha256:e9b943c97164f598b5c7280c762ee65f51c69a8a  0.3s
#  => => exporting config sha256:53b35e07b389a0403678d22e963b341120c55d12be  0.3s
#  => => exporting attestation manifest sha256:16a18f5557310d3b6b25ee5d9ae2  0.6s
#  => => exporting manifest list sha256:ee5bcf38e28163cb13d271f2925caa32e30  0.3s
#  => => naming to docker.io/library/foreign-whispers-api:latest             0.0s
#  => => unpacking to docker.io/library/foreign-whispers-api:latest          1.7s
# [+] Building 38.5s (16/16)
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          8.9s
#  => => transferring context: 166.59MB                                      8.6s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
#  => CACHED [stage-0 2/8] RUN apt-get update &&     apt-get install --no-i  0.0s
#  => CACHED [stage-0 3/8] RUN groupadd --gid 1000 appuser     && useradd -  0.0s
#  => CACHED [stage-0 4/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx  0.0s
#  => CACHED [stage-0 5/8] WORKDIR /app                                      0.0s
#  => CACHED [stage-0 6/8] COPY --chown=appuser:appuser pyproject.toml uv.l  0.0s
#  => CACHED [stage-0 7/8] RUN --mount=type=cache,target=/root/.cache/uv     0.0s
#  => [stage-0 8/8] COPY --chown=appuser:appuser . .                         7.2s
#  => exporting to image                                                    17.2s
#  => => exporting layers                                                   13.6s
#  => => exporting manifest sha256:e9b943c97164f598b5c7280c762ee65f51c69a8a  0.3s
#  => => exporting config sha256:53b35e07b389a0403678d22e963b341120c55d12be  0.3s
#  => => exporting attestation manifest sha256:16a18f5557310d3b6b25ee5d9ae2  0.6s
#  => => exporting manifest list sha256:ee5bcf38e28163cb13d271f2925caa32e30  0.3s
#  => => naming to docker.io/library/foreign-whispers-api:latest             0.0s
#  => => unpacking to docker.io/library/foreign-whispers-api:latest          1.7s
# [+] Building 38.6s (16/17)
#  => [internal] load build context                                          8.9s
#  => => transferring context: 166.59MB                                      8.6s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
#  => CACHED [stage-0 2/8] RUN apt-get update &&     apt-get install --no-i  0.0s
#  => CACHED [stage-0 3/8] RUN groupadd --gid 1000 appuser     && useradd -  0.0s
#  => CACHED [stage-0 4/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx  0.0s
#  => CACHED [stage-0 5/8] WORKDIR /app                                      0.0s
#  => CACHED [stage-0 6/8] COPY --chown=appuser:appuser pyproject.toml uv.l  0.0s
#  => CACHED [stage-0 7/8] RUN --mount=type=cache,target=/root/.cache/uv     0.0s
#  => [stage-0 8/8] COPY --chown=appuser:appuser . .                         7.2s
#  => exporting to image                                                    17.2s
#  => => exporting layers                                                   13.6s
#  => => exporting manifest sha256:e9b943c97164f598b5c7280c762ee65f51c69a8a  0.3s
#  => => exporting config sha256:53b35e07b389a0403678d22e963b341120c55d12be  0.3s
#  => => exporting attestation manifest sha256:16a18f5557310d3b6b25ee5d9ae2  0.6s
#  => => exporting manifest list sha256:ee5bcf38e28163cb13d271f2925caa32e30  0.3s
#  => => naming to docker.io/library/foreign-whispers-api:latest             0.0s
#  => => unpacking to docker.io/library/foreign-whispers-api:latest          1.7s
#  => resolving provenance for metadata file                                 0.0s
# [+] Building 38.8s (17/17) FINISHED
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 612B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 1.18kB                                     0.0s
#  => [internal] load metadata for ghcr.io/astral-sh/uv:latest               1.6s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        1.5s
#  => [internal] load .dockerignore                                          0.1s
#  => => transferring context: 131B                                          0.0s
#  => [internal] load build context                                          8.9s
#  => => transferring context: 166.59MB                                      8.6s
#  => [stage-0 1/8] FROM docker.io/library/python:3.11-slim@sha256:6d85378d  2.1s
#  => => resolve docker.io/library/python:3.11-slim@sha256:6d85378d88a19cd4  1.9s
#  => FROM ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e5c83fd  2.0s
#  => => resolve ghcr.io/astral-sh/uv:latest@sha256:3b7b60a81d3c57ef471703e  1.8s
#  => CACHED [stage-0 2/8] RUN apt-get update &&     apt-get install --no-i  0.0s
#  => CACHED [stage-0 3/8] RUN groupadd --gid 1000 appuser     && useradd -  0.0s
#  => CACHED [stage-0 4/8] COPY --from=ghcr.io/astral-sh/uv:latest /uv /uvx  0.0s
#  => CACHED [stage-0 5/8] WORKDIR /app                                      0.0s
#  => CACHED [stage-0 6/8] COPY --chown=appuser:appuser pyproject.toml uv.l  0.0s
#  => CACHED [stage-0 7/8] RUN --mount=type=cache,target=/root/.cache/uv     0.0s
#  => [stage-0 8/8] COPY --chown=appuser:appuser . .                         7.2s
#  => exporting to image                                                    17.2s
#  => => exporting layers                                                   13.6s
#  => => exporting manifest sha256:e9b943c97164f598b5c7280c762ee65f51c69a8a  0.3s
#  => => exporting config sha256:53b35e07b389a0403678d22e963b341120c55d12be  0.3s
#  => => exporting attestation manifest sha256:16a18f5557310d3b6b25ee5d9ae2  0.6s
#  => => exporting manifest list sha256:ee5bcf38e28163cb13d271f2925caa32e30  0.3s
#  => => naming to docker.io/library/foreign-whispers-api:latest             0.0s
#  => => unpacking to docker.io/library/foreign-whispers-api:latest          1.7s
#  => resolving provenance for metadata file                                 0.0s
# [+] build 1/1
#  ✔ Image foreign-whispers-api Built                                        39.1s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Recreate                                  0.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Recreate                                  0.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Recreate                                  0.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Recreate                                  0.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Recreate                                  0.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-api Recreate                                  0.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-api Recreate                                  0.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-api Recreate                                  0.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-api Recreate                                  0.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-api Recreate                                  0.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Recreate                                  1.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Recreate                                  1.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Recreate                                  1.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Recreate                                  1.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Recreate                                  1.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-api Recreate                                  1.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-api Recreate                                  1.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-api Recreate                                  1.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-api Recreate                                  1.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-api Recreate                                  1.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Recreate                                  2.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Recreate                                  2.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Recreate                                  2.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Recreate                                  2.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Recreate                                  2.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-api Recreate                                  2.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-api Recreate                                  2.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-api Recreate                                  2.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-api Recreate                                  2.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-api Recreate                                  2.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Recreate                                  3.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Recreate                                  3.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Recreate                                  3.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Recreate                                  3.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Recreate                                  3.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-api Recreate                                  3.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-api Recreate                                  3.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-api Recreate                                  3.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-api Recreate                                  3.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-api Recreate                                  3.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Recreate                                  4.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Recreate                                  4.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Recreate                                  4.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Recreate                                  4.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Recreate                                  4.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-api Recreate                                  4.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-api Recreate                                  4.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-api Recreate                                  4.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-api Recreate                                  4.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-api Recreate                                  4.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Recreate                                  5.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Recreate                                  5.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Recreate                                  5.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Recreate                                  5.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Recreate                                  5.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-api Recreate                                  5.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-api Recreate                                  5.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-api Recreate                                  5.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-api Recreate                                  5.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-api Recreate                                  5.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Recreate                                  6.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Recreate                                  6.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Recreate                                  6.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Recreate                                  6.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Recreate                                  6.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-api Recreate                                  6.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-api Recreate                                  6.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-api Recreate                                  6.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-api Recreate                                  6.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-api Recreate                                  6.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Recreate                                  7.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Recreate                                  7.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Recreate                                  7.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Recreate                                  7.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Recreate                                  7.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-api Recreate                                  7.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-api Recreate                                  7.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-api Recreate                                  7.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-api Recreate                                  7.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-api Recreate                                  7.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Recreate                                  8.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Recreate                                  8.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Recreate                                  8.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Recreate                                  8.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Recreate                                  8.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-api Starting                                  8.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-api Starting                                  8.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-api Starting                                  8.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-api Starting                                  8.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-api Starting                                  8.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-api Starting                                  9.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-api Starting                                  9.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-api Starting                                  9.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-api Starting                                  9.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-api Starting                                  9.4s
# [+] up 1/1
#  ✔ Container foreign-whispers-api Started                                   9.4s

# %%
import requests

API_BASE = "http://localhost:8080"

# Get the first video ID from the registry
videos = requests.get(f"{API_BASE}/api/videos").json()
video_id = videos[0]["id"]
print(f"Testing with video: {videos[0]['title']} ({video_id})")

# Call the diarize endpoint
resp = requests.post(f"{API_BASE}/api/diarize/{video_id}")
print(f"Status: {resp.status_code}")
print(resp.json())
# Out:
# Testing with video: Strait of Hormuz disruption threatens to shake global economy (GYQ5yGV_-Oc)
# Status: 200
# {'video_id': 'GYQ5yGV_-Oc', 'speakers': [], 'segments': [], 'skipped': True}

# %% [markdown]
# ### 2.7 — Commit
#
# ```bash
# git add api/src/schemas/diarize.py api/src/routers/diarize.py api/src/main.py api/src/core/config.py
# git commit -m "feat: add POST /api/diarize endpoint with caching"
# ```

# %% [markdown]
# ---
#
# ## Task 3: Merge Speaker Labels Into Transcription
#
# **Goal:** After diarization runs, update the transcription JSON so each segment has a `speaker` field. This way downstream stages (translate, TTS) know which speaker said what.
#
# **File to modify:** `api/src/routers/diarize.py`

# %% [markdown]
# ### 3.1 — Add merge step to the diarize endpoint
#
# After your diarization result is cached, add this code to update the transcription JSON with speaker labels:
#
# ```python
# from foreign_whispers.diarization import assign_speakers
#
# transcript_path = settings.transcriptions_dir / f"{title}.json"
# if transcript_path.exists():
#     transcript = json.loads(transcript_path.read_text())
#     labeled_segments = assign_speakers(transcript.get("segments", []), diar_segments)
#     transcript["segments"] = labeled_segments
#     transcript_path.write_text(json.dumps(transcript))
# ```

# %% [markdown]
# ### 3.2 — Verify the merge

# %%
import json

# After running diarize, check the transcription for speaker labels
# Replace TITLE with your video's title
transcription_dir = PROJECT_ROOT / "pipeline_data" / "api" / "transcriptions" / "whisper"
transcription_files = list(transcription_dir.glob("*.json"))

if transcription_files:
    data = json.loads(transcription_files[0].read_text())
    print(f"File: {transcription_files[0].name}")
    print(f"Number of segments: {len(data.get('segments', []))}")
    print("\nFirst 3 segments:")
    for seg in data.get("segments", [])[:3]:
        speaker = seg.get("speaker", "<NO SPEAKER>")
        print(f"  [{seg['start']:.1f}s - {seg['end']:.1f}s] {speaker}: {seg['text'][:60]}")
else:
    print("No transcription files found — run the pipeline first.")
# Out:
# File: Strait of Hormuz disruption threatens to shake global economy.json
# Number of segments: 170
#
# First 3 segments:
#   [2.3s - 6.1s] SPEAKER_00: 60 Minutes overtime.
#   [6.5s - 10.2s] SPEAKER_00: What's the worst case scenario that
#   [8.0s - 12.4s] SPEAKER_00: you're worried about is that it is

# %% [markdown]
# ### 3.3 — Commit
#
# ```bash
# git add api/src/routers/diarize.py
# git commit -m "feat: merge speaker labels into transcription after diarization"
# ```

# %% [markdown]
# ---
#
# ## Task 4: Frontend Pipeline Integration
#
# **Goal:** Call the diarize endpoint from the frontend pipeline when diarization is enabled in settings.
#
# **Files to modify:**
# - `frontend/src/lib/api.ts` — add `diarizeVideo` function
# - `frontend/src/lib/types.ts` — add `"diarize"` to `PipelineStage`
# - `frontend/src/hooks/use-pipeline.ts` — call diarize between transcribe and translate
# - `frontend/src/components/pipeline-table.tsx` — add diarize row
# - `frontend/src/components/pipeline-status-bar.tsx` — add status message

# %% [markdown]
# ### 4.1 — Add the API client function
#
# In `frontend/src/lib/api.ts`, add:
#
# ```typescript
# export async function diarizeVideo(videoId: string): Promise<DiarizeResponse> {
#   return fetchJson<DiarizeResponse>(`/api/diarize/${videoId}`, {
#     method: "POST",
#   });
# }
# ```

# %% [markdown]
# ### 4.2 — Add TypeScript types
#
# In `frontend/src/lib/types.ts`, add:
#
# ```typescript
# export interface DiarizeResponse {
#   video_id: string;
#   speakers: string[];
#   segments: { start_s: number; end_s: number; speaker: string }[];
#   skipped: boolean;
# }
# ```
#
# Update `PipelineStage`:
#
# ```typescript
# export type PipelineStage = "download" | "transcribe" | "diarize" | "translate" | "tts" | "stitch";
# ```

# %% [markdown]
# ### 4.3 — Wire into the pipeline hook
#
# In `frontend/src/hooks/use-pipeline.ts`, add the diarize call **between** transcribe and translate:
#
# ```typescript
# // After: await run("transcribe", () => transcribeVideo(dl.video_id, settings.useYoutubeCaptions));
# // Before: await run("translate", () => translateVideo(dl.video_id, "es"));
#
# if (settings.diarization.length > 0) {
#   await run("diarize", () => diarizeVideo(dl.video_id));
# }
# ```
#
# Don't forget to import `diarizeVideo` at the top of the file.

# %% [markdown]
# ### 4.4 — Add UI elements
#
# In `frontend/src/components/pipeline-table.tsx`, add a row to `STAGES`:
#
# ```typescript
# import { UsersIcon } from "lucide-react";
#
# // Add after "transcribe" entry:
# { key: "diarize", label: "Diarize", icon: UsersIcon, description: "Speaker diarization via pyannote" },
# ```
#
# In `frontend/src/components/pipeline-status-bar.tsx`, add:
#
# ```typescript
# diarize: "Running pyannote speaker diarization...",
# ```

# %% [markdown]
# ### 4.5 — Build and test

# %%
# Rebuild the frontend
# !cd {PROJECT_ROOT} && docker compose --profile nvidia build frontend
# !cd {PROJECT_ROOT} && docker compose --profile nvidia up -d frontend

print("\nOpen http://localhost:8501")
print("1. Click the gear icon to open Settings")
print("2. Go to TTS > Diarization and select 'pyannote'")
print("3. Run the pipeline — the Diarize stage should appear in the table")
# Out:
# [+] Building 0.0s (0/1)
#  => [internal] load local bake definitions                                 0.0s
# [+] Building 0.2s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
# [+] Building 0.3s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
# [+] Building 0.5s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
# [+] Building 0.6s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
# [+] Building 0.8s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
# [+] Building 0.9s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
# [+] Building 1.0s (1/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
# [+] Building 1.2s (1/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.2s
#  => => transferring dockerfile: 674B                                       0.1s
# [+] Building 1.4s (1/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.4s
#  => => transferring dockerfile: 674B                                       0.1s
# [+] Building 1.4s (2/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
# [+] Building 1.5s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          0.0s
# [+] Building 1.7s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          0.2s
# [+] Building 1.8s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          0.3s
# [+] Building 2.0s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          0.5s
# [+] Building 2.1s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          0.6s
# [+] Building 2.3s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          0.8s
# [+] Building 2.4s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          0.9s
# [+] Building 2.6s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.1s
# [+] Building 2.7s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.2s
# [+] Building 2.9s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
# [+] Building 2.9s (3/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
# [+] Building 3.1s (4/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
# [+] Building 3.3s (5/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.2s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.0s
#  => [internal] load build context                                          0.0s
# [+] Building 3.5s (5/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.3s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.2s
#  => [internal] load build context                                          0.0s
# [+] Building 3.6s (5/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.5s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.3s
#  => [internal] load build context                                          0.0s
# [+] Building 3.8s (5/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.6s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.0s
# [+] Building 3.8s (5/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.0s
# [+] Building 4.0s (5/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
# [+] Building 4.1s (6/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
# [+] Building 4.2s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
# [+] Building 4.3s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   0.2s
# [+] Building 4.5s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   0.3s
# [+] Building 4.6s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   0.5s
# [+] Building 4.8s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   0.6s
# [+] Building 4.9s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   0.8s
# [+] Building 5.1s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   0.9s
# [+] Building 5.2s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.1s
# [+] Building 5.4s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.2s
# [+] Building 5.5s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.4s
# [+] Building 5.7s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.5s
# [+] Building 5.8s (11/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.7s
# [+] Building 6.0s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
# [+] Building 6.2s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                             0.2s
# [+] Building 6.3s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                             0.3s
# [+] Building 6.5s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                             0.5s
# [+] Building 6.6s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                             0.6s
# [+] Building 6.8s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                             0.8s
# [+] Building 6.9s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                             0.9s
# [+] Building 7.1s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                             1.1s
# [+] Building 7.2s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                             1.2s
# [+] Building 7.4s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                             1.4s
# [+] Building 7.5s (12/16)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
# ...
#  => => exporting config sha256:01f876d9106e1910f537799997103aa22bf8bee9cc  0.3s
#  => => exporting attestation manifest sha256:26acadd27565fa9e4172c89eab89  0.6s
#  => => exporting manifest list sha256:7e7c2b5bfbb858121b38395b914ff2c2b98  0.3s
#  => => naming to docker.io/library/foreign-whispers-frontend:latest        0.1s
#  => => unpacking to docker.io/library/foreign-whispers-frontend:latest     2.1s
#  => resolving provenance for metadata file                                 0.1s
# [+] Building 86.7s (18/18)
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                            56.0s
#  => [runner 1/3] COPY --from=build /app/.next/standalone ./                4.0s
#  => [runner 2/3] COPY --from=build /app/.next/static ./.next/static        1.9s
#  => [runner 3/3] COPY --from=build /app/public ./public                    1.9s
#  => exporting to image                                                    12.9s
#  => => exporting layers                                                    8.9s
#  => => exporting manifest sha256:5ea75005dc9ca07f9dd3bc3f857320730f6ea9c8  0.3s
#  => => exporting config sha256:01f876d9106e1910f537799997103aa22bf8bee9cc  0.3s
#  => => exporting attestation manifest sha256:26acadd27565fa9e4172c89eab89  0.6s
#  => => exporting manifest list sha256:7e7c2b5bfbb858121b38395b914ff2c2b98  0.3s
#  => => naming to docker.io/library/foreign-whispers-frontend:latest        0.1s
#  => => unpacking to docker.io/library/foreign-whispers-frontend:latest     2.1s
#  => resolving provenance for metadata file                                 0.1s
# [+] Building 86.9s (18/18)
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                            56.0s
#  => [runner 1/3] COPY --from=build /app/.next/standalone ./                4.0s
#  => [runner 2/3] COPY --from=build /app/.next/static ./.next/static        1.9s
#  => [runner 3/3] COPY --from=build /app/public ./public                    1.9s
#  => exporting to image                                                    12.9s
#  => => exporting layers                                                    8.9s
#  => => exporting manifest sha256:5ea75005dc9ca07f9dd3bc3f857320730f6ea9c8  0.3s
#  => => exporting config sha256:01f876d9106e1910f537799997103aa22bf8bee9cc  0.3s
#  => => exporting attestation manifest sha256:26acadd27565fa9e4172c89eab89  0.6s
#  => => exporting manifest list sha256:7e7c2b5bfbb858121b38395b914ff2c2b98  0.3s
#  => => naming to docker.io/library/foreign-whispers-frontend:latest        0.1s
#  => => unpacking to docker.io/library/foreign-whispers-frontend:latest     2.1s
#  => resolving provenance for metadata file                                 0.1s
# [+] Building 87.0s (18/18) FINISHED
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 570B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.3s
#  => => transferring dockerfile: 674B                                       0.1s
#  => [internal] load metadata for docker.io/library/node:22-alpine          1.4s
#  => [internal] load .dockerignore                                          0.2s
#  => => transferring context: 64B                                           0.0s
#  => [base 1/3] FROM docker.io/library/node:22-alpine@sha256:8ea2348b068a9  0.7s
#  => => resolve docker.io/library/node:22-alpine@sha256:8ea2348b068a9544da  0.5s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 40.53kB                                       0.1s
#  => CACHED [base 2/3] RUN corepack enable && corepack prepare pnpm@latest  0.0s
#  => CACHED [base 3/3] WORKDIR /app                                         0.0s
#  => CACHED [deps 1/2] COPY package.json pnpm-lock.yaml ./                  0.0s
#  => CACHED [deps 2/2] RUN pnpm install --frozen-lockfile                   0.0s
#  => CACHED [build 1/3] COPY --from=deps /app/node_modules ./node_modules   0.0s
#  => [build 2/3] COPY . .                                                   1.8s
#  => [build 3/3] RUN pnpm build                                            56.0s
#  => [runner 1/3] COPY --from=build /app/.next/standalone ./                4.0s
#  => [runner 2/3] COPY --from=build /app/.next/static ./.next/static        1.9s
#  => [runner 3/3] COPY --from=build /app/public ./public                    1.9s
#  => exporting to image                                                    12.9s
#  => => exporting layers                                                    8.9s
#  => => exporting manifest sha256:5ea75005dc9ca07f9dd3bc3f857320730f6ea9c8  0.3s
#  => => exporting config sha256:01f876d9106e1910f537799997103aa22bf8bee9cc  0.3s
#  => => exporting attestation manifest sha256:26acadd27565fa9e4172c89eab89  0.6s
#  => => exporting manifest list sha256:7e7c2b5bfbb858121b38395b914ff2c2b98  0.3s
#  => => naming to docker.io/library/foreign-whispers-frontend:latest        0.1s
#  => => unpacking to docker.io/library/foreign-whispers-frontend:latest     2.1s
#  => resolving provenance for metadata file                                 0.1s
# [+] build 1/1
#  ✔ Image foreign-whispers-frontend Built                                   87.5s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Recreate                             0.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Recreate                             0.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Recreate                             0.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Recreate                             0.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Recreate                             0.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Recreate                             0.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Recreate                             0.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-frontend Recreate                             0.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-frontend Recreate                             0.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-frontend Recreate                             0.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Recreate                             1.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Recreate                             1.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Recreate                             1.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Recreate                             1.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Recreate                             1.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Recreate                             1.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Recreate                             1.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-frontend Recreate                             1.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-frontend Recreate                             1.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-frontend Recreate                             1.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Recreate                             2.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Recreate                             2.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Recreate                             2.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Recreate                             2.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Recreate                             2.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Recreate                             2.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Recreate                             2.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-frontend Recreate                             2.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-frontend Recreate                             2.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-frontend Recreate                             2.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Recreate                             3.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Recreate                             3.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Recreate                             3.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Recreate                             3.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Recreate                             3.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Recreate                             3.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Recreate                             3.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-frontend Recreate                             3.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-frontend Recreate                             3.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-frontend Recreate                             3.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Recreate                             4.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Recreate                             4.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Recreate                             4.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Recreate                             4.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Recreate                             4.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Recreate                             4.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Recreate                             4.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-frontend Recreate                             4.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-frontend Recreate                             4.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-frontend Recreate                             4.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Recreate                             5.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Recreate                             5.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Recreate                             5.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Recreate                             5.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Recreate                             5.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Recreate                             5.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Recreate                             5.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-frontend Recreate                             5.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-frontend Recreate                             5.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-frontend Recreate                             5.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Recreate                             6.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Recreate                             6.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Recreate                             6.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Recreate                             6.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Recreate                             6.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Recreate                             6.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Recreate                             6.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-frontend Recreate                             6.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-frontend Recreate                             6.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-frontend Recreate                             6.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Recreate                             7.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Recreate                             7.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Recreate                             7.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Recreate                             7.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Recreate                             7.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Recreate                             7.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Recreate                             7.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-frontend Recreate                             7.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-frontend Recreate                             7.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-frontend Recreate                             7.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Recreate                             8.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Recreate                             8.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Recreate                             8.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Recreate                             8.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Recreate                             8.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Recreate                             8.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Recreate                             8.6s
# [+] up 0/1
#  ⠧ Container foreign-whispers-frontend Starting                             8.7s
# [+] up 0/1
#  ⠇ Container foreign-whispers-frontend Starting                             8.8s
# [+] up 0/1
#  ⠏ Container foreign-whispers-frontend Starting                             8.9s
# [+] up 0/1
#  ⠋ Container foreign-whispers-frontend Starting                             9.0s
# [+] up 0/1
#  ⠙ Container foreign-whispers-frontend Starting                             9.1s
# [+] up 0/1
#  ⠹ Container foreign-whispers-frontend Starting                             9.2s
# [+] up 0/1
#  ⠸ Container foreign-whispers-frontend Starting                             9.3s
# [+] up 0/1
#  ⠼ Container foreign-whispers-frontend Starting                             9.4s
# [+] up 0/1
#  ⠴ Container foreign-whispers-frontend Starting                             9.5s
# [+] up 0/1
#  ⠦ Container foreign-whispers-frontend Starting                             9.6s
# [+] up 1/1
#  ✔ Container foreign-whispers-frontend Started                              9.6s
#
# Open http://localhost:8501
# 1. Click the gear icon to open Settings
# 2. Go to TTS > Diarization and select 'pyannote'
# 3. Run the pipeline — the Diarize stage should appear in the table

# %% [markdown]
# ### 4.6 — Commit
#
# ```bash
# git add frontend/src/lib/api.ts frontend/src/lib/types.ts \
#   frontend/src/hooks/use-pipeline.ts \
#   frontend/src/components/pipeline-table.tsx \
#   frontend/src/components/pipeline-status-bar.tsx
# git commit -m "feat: add diarize stage to frontend pipeline"
# ```

# %% [markdown]
# ---
#
# ## Task 5: Per-Speaker TTS Voice Selection
#
# **Goal:** When speaker labels exist in the translated segments, use a different Chatterbox reference voice per speaker.
#
# **Files to modify:**
# - `api/src/routers/tts.py`
# - `api/src/services/tts_service.py`
#
# **Approach:**
# 1. Read the translated JSON — each segment now has a `speaker` field
# 2. Map each unique speaker to a reference WAV from `pipeline_data/speakers/{lang}/`
# 3. Pass the speaker-to-voice mapping to the TTS engine so it switches voices per segment

# %%
# Explore available speaker reference voices
speakers_dir = PROJECT_ROOT / "pipeline_data" / "speakers"
print("Available languages:")
for lang_dir in sorted(speakers_dir.iterdir()):
    if lang_dir.is_dir():
        wavs = list(lang_dir.glob("*.wav"))
        print(f"  {lang_dir.name}/  ({len(wavs)} reference WAVs)")
        for wav in wavs[:3]:
            print(f"    - {wav.name}")
# Out:
# Available languages:

# %% [markdown]
# ### 5.1 — Design your voice assignment strategy
#
# Some options to consider:
# - **Round-robin:** Assign voices in order (SPEAKER_00 → voice_1.wav, SPEAKER_01 → voice_2.wav)
# - **Filename-based:** Match speaker index to file index
# - **Default + override:** Use `default.wav` for all speakers unless specific speaker WAVs are provided
#
# Document your chosen approach in the cell below:

# %% [markdown]
# *YOUR DESIGN NOTES HERE*
#
# - Strategy chosen: ...
# - How speakers map to voice files: ...
# - Edge cases considered: ...

# %% [markdown]
# ### 5.2 — Implement and test
#
# Modify `tts_service.py` to accept a speaker-to-voice mapping and switch reference audio per segment. This is open-ended — use the existing `text_file_to_speech` function as your starting point.

# %% [markdown]
# ---
#
# ## Evaluation Criteria
#
# | # | Criterion | How to verify |
# | - | --------- | ------------- |
# | 1 | Tests pass | Re-run the test cell in Task 1.4 — all 4 green |
# | 2 | API works | `POST /api/diarize/{video_id}` returns speaker segments |
# | 3 | Merge works | Transcription JSON has `speaker` fields after diarization |
# | 4 | Frontend works | Diarize stage appears in pipeline table when enabled |
# | 5 | Caching works | Second API call returns `skipped: true` |
# | 6 | Code quality | Follows existing patterns (file-exists cache, service layer, Pydantic schemas) |
